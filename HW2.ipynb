# %% [markdown]
# # 1. Разметка

# %%
from nltk.tokenize import NLTKWordTokenizer
import json

# %%
tokenizer = NLTKWordTokenizer()

# %%
text_1 = '''Не прилично ли будет нам, братия,
Начать древним складом
Печальную повесть о битвах Игоря,
Игоря Святославича!
Начаться же сей песни
По былинам сего времени,
А не по вымыслам Бояновым.
Вещий Боян,
Если песнь кому сотворить хотел,
Растекался мыслию по древу,
Серым волком по земли,
Сизым орлом под облаками.'''

text_2 = '''Вашу мысль,
мечтающую на размягченном мозгу,
как выжиревший лакей на засаленной кушетке,
буду дразнить об окровавленный сердца лоскут:
досыта изъиздеваюсь, нахальный и едкий.
У меня в душе ни одного седого волоса,
и старческой нежности нет в ней!
Мир огромив мощью голоса,
иду — красивый,
двадцатидвухлетний.
Нежные!
Вы любовь на скрипки ложите.
Любовь на литавры ложит грубый.
А себя, как я, вывернуть не можете,
чтобы были одни сплошные губы!
Приходите учиться —
из гостиной батистовая,
чинная чиновница ангельской лиги.'''

text_3 = '''Низкий дом без меня ссутулится,
Старый пёс мой давно издох.
На московских изогнутых улицах
Умереть, знать, сулил мне Бог.
Я люблю этот город вязевый,
Пусть обрюзг он и пусть одрях.
Золотая дремотная Азия
Опочила на куполах.
А когда ночью светит месяц,
Когда светит… чёрт знает как!
Я иду, головою свесясь,
Переулком в знакомый кабак.
Шум и гам в этом логове жутком,
Но всю ночь напролёт, до зари,
Я читаю стихи проституткам
И с бандитами жарю спирт.'''

text_4 = '''Седое в джинсах от кутюр
Абсурд, карикатура
Смешно... в стране мультикультур
Закончилась культура
И свет погас, и гроб готов
И мне клауд-грустно
В стране есенинских стихов
Закончилось искусство
Рояльчик в парке городском
Расстроен очень-очень
И кто-то страшный жмёт на нём
Бемоль чернее ночи
И в чёрном худи бродит там
Провинциальный Бэнкси
Баллоном строчки по углам
Слова из этой песни'''
corpus = [text_1, text_2, text_3, text_4]

# %% [markdown]
# Я выбрал 4 очень разных текста с разными особенностями:<br>
# * В первом тексте сложность представляют нерегулярные формы (братия, песнь, мыслию, [по] земли)
# * Во втором тексте много редких форм (выжиревший, изъиздеваюсь) и авторчких слов (огромив), а также нелитературные формы (ложите)
# * В третьем тексте встречаются редкие глагольные лексемы (обрюзг, опочила)
# * В четвёртом тексте присутствуют авторские слова (клауд-грустно), редкие лексемы (мультикультур, есенинских), а также нетривиальные синтаксические структуры (Баллоном строчки по углам / Слова из этой песни)

# %% [markdown]
# Далее я вручную производил разметку в формате словаря:
# ```python
# {номер токена:
#                  {слово: 'слово', возможные_тэги:
#                                                   (тэг_1, тэг_2,...)
#                   }
# }
# ```

# %% [markdown]
# <b>Это был код разметки</b><br>
# tagged = {} <br>
# i = 0<br>
# for text in corpus:<br>
#     for token in tokenizer.tokenize(text.lower()):<br>
#         if token.strip('.,!?:…—') != '':<br>
#             word = token.strip(".,!?:…—")<br>
#             tags = tuple(input(f'{i}. POS tag of "{word}": ').split(' '))<br>
#             tagged[i] = {'word': word, 'tags': tags}<br>
#             i += 1

# %% [markdown]
# При разметке я пользовался указаниями из домашней статьи, так как их целью было избежать неоднозначных моментов, а кроме того, к ней легко сводимы другие типы разметки. Разметка выглядит вот так [Ляшевская и др. 2010]:<br>
# * существительные (S)<br>
# * прилагательные (A)<br>
# * глаголы, в том числе причастия и деепричастия (V)<br>
# * предлоги (PR)<br>
# * союзы (CONJ)<br>
# * сборная категория, включающая прочие несклоняемые слова: наречия, вводные слова, частицы, междометия (ADV)<br>
# <br>
# Не участвовали в оценке и могли быть размечены любым образом местоимения (включая наречные и предикативные), числительные, а также составные предлоги и союзы (ср. потому что, в течение).

# %% [markdown]
# <b>На этом этапе я записал свою разметку в json файл</b><br>
# with open('tagged.json', 'w', encoding='utf-8') as f: <br>
#     json.dump(tagged, f, ensure_ascii=False, indent='\t')

# %%
with open('tagged.json', 'r', encoding='utf-8') as f: # достаю свою разметку из файла
    tagged = json.load(f)

# %%
for i in range(259): # перевожу индексы токенов из строк в числа
    tagged[i] = tagged[str(i)]
    tagged.pop(str(i))

# %%
len(tagged)
# Out:
# 259

# %% [markdown]
# # 2. Тэггеры

# %% [markdown]
# ## 2.1. pymorphy

# %%
from pymorphy2 import MorphAnalyzer

# %% [markdown]
# Создаю словарь-конвертер

# %%
pymorphy_conv = {
    'NOUN': 'S',
    'ADJF': 'A',
    'ADJS': 'A',
    'COMP': 'A',
    'VERB': 'V',
    'INFN': 'V',
    'PRTF': 'V',
    'PRTS': 'V',
    'GRND': 'V',
    'NUMR': '-',
    'ADVB': 'ADV',
    'NPRO': '-',
    'PRED': 'ADV',
    'PREP': 'PR',
    'CONJ': 'CONJ',
    'PRCL': 'ADV',
    'INTJ': 'ADV'
}

# %%
m = MorphAnalyzer()

# %% [markdown]
# Токенизирую и определяю части речи

# %%
pymorphy_tagged = {}
i = 0
for text in corpus:
    for token in tokenizer.tokenize(text.lower()):
        if token.strip('.,!?:…—') != '':
            pos = m.parse(token.strip('.,!?:…'))[0].tag.POS
            if pos != None:
                pymorphy_tagged[i] = pymorphy_conv[pos]
            else:
                pymorphy_tagged[i] = '-'
            i += 1

# %%
pymorphy_tagged
# Out:
# {0: 'ADV',
#  1: 'ADV',
#  2: 'CONJ',
#  3: 'V',
#  4: '-',
#  5: 'S',
#  6: 'V',
#  7: 'A',
#  8: 'S',
#  9: 'A',
#  10: 'S',
#  11: 'PR',
#  12: 'S',
#  13: 'S',
#  14: 'S',
#  15: 'S',
#  16: 'V',
#  17: 'ADV',
#  18: 'A',
#  19: 'S',
#  20: 'PR',
#  21: 'S',
#  22: '-',
#  23: 'S',
#  24: 'CONJ',
#  25: 'ADV',
#  26: 'PR',
#  27: 'S',
#  28: 'S',
#  29: 'A',
#  30: 'S',
#  31: 'CONJ',
#  32: 'S',
#  33: '-',
#  34: 'V',
#  35: 'V',
#  36: 'V',
#  37: 'S',
#  38: 'PR',
#  39: 'S',
#  40: 'A',
#  41: 'S',
#  42: 'PR',
#  43: 'S',
#  44: 'A',
#  45: 'S',
#  46: 'PR',
#  47: 'S',
#  48: 'A',
#  49: 'S',
#  50: 'V',
#  51: 'PR',
#  52: 'V',
#  53: 'S',
#  54: 'CONJ',
#  55: 'V',
#  56: 'S',
#  57: 'PR',
#  58: 'A',
#  59: 'S',
#  60: 'V',
#  61: 'V',
#  62: 'PR',
#  63: 'A',
#  64: 'S',
#  65: 'S',
#  66: 'ADV',
#  67: 'V',
#  68: 'A',
#  69: 'CONJ',
#  70: 'A',
#  71: 'PR',
#  72: '-',
#  73: 'PR',
#  74: 'S',
#  75: 'ADV',
#  76: 'A',
#  77: 'A',
#  78: 'S',
#  79: 'CONJ',
#  80: 'A',
#  81: 'S',
#  82: 'ADV',
#  83: 'PR',
#  84: '-',
#  85: 'S',
#  86: 'V',
#  87: 'S',
#  88: 'S',
#  89: 'V',
#  90: 'A',
#  91: 'A',
#  92: 'A',
#  93: '-',
#  94: 'S',
#  95: 'PR',
#  96: 'S',
#  97: 'V',
#  98: 'S',
#  99: 'PR',
#  100: 'S',
#  101: 'V',
#  102: 'A',
#  103: 'CONJ',
#  104: '-',
#  105: 'CONJ',
#  106: '-',
#  107: 'V',
#  108: 'ADV',
#  109: 'V',
#  110: 'CONJ',
#  111: 'V',
#  112: 'A',
#  113: 'A',
#  114: 'S',
#  115: 'V',
#  116: 'V',
#  117: 'PR',
#  118: 'S',
#  119: 'A',
#  120: 'A',
#  121: 'S',
#  122: 'A',
#  123: 'S',
#  124: 'A',
#  125: 'S',
#  126: 'PR',
#  127: '-',
#  128: 'V',
#  129: 'A',
#  130: 'S',
#  131: 'A',
#  132: 'ADV',
#  133: 'V',
#  134: 'PR',
#  135: 'A',
#  136: 'A',
#  137: 'S',
#  138: 'V',
#  139: 'V',
#  140: 'V',
#  141: '-',
#  142: 'S',
#  143: '-',
#  144: 'V',
#  145: 'A',
#  146: 'S',
#  147: 'A',
#  148: 'ADV',
#  149: 'V',
#  150: '-',
#  151: 'CONJ',
#  152: 'ADV',
#  153: 'V',
#  154: 'A',
#  155: 'A',
#  156: 'S',
#  157: 'V',
#  158: 'PR',
#  159: 'S',
#  160: 'CONJ',
#  161: 'CONJ',
#  162: 'ADV',
#  163: 'V',
#  164: 'S',
#  165: 'CONJ',
#  166: 'V',
#  167: 'S',
#  168: 'V',
#  169: 'CONJ',
#  170: '-',
#  171: 'V',
#  172: 'S',
#  173: 'V',
#  174: 'S',
#  175: 'PR',
#  176: 'A',
#  177: 'S',
#  178: 'S',
#  179: 'CONJ',
#  180: 'S',
#  181: 'PR',
#  182: '-',
#  183: 'S',
#  184: 'A',
#  185: 'CONJ',
#  186: 'A',
#  187: 'S',
#  188: 'ADV',
#  189: 'PR',
#  190: 'S',
#  191: '-',
#  192: 'V',
#  193: 'S',
#  194: 'S',
#  195: 'CONJ',
#  196: 'PR',
#  197: 'S',
#  198: 'V',
#  199: 'S',
#  200: 'A',
#  201: 'PR',
#  202: 'S',
#  203: 'PR',
#  204: 'S',
#  205: 'S',
#  206: 'S',
#  207: 'ADV',
#  208: 'PR',
#  209: 'S',
#  210: 'S',
#  211: 'V',
#  212: 'S',
#  213: 'CONJ',
#  214: 'S',
#  215: 'V',
#  216: 'CONJ',
#  217: 'S',
#  218: 'A',
#  219: 'CONJ',
#  220: '-',
#  221: 'ADV',
#  222: 'PR',
#  223: 'S',
#  224: 'A',
#  225: 'S',
#  226: 'V',
#  227: 'S',
#  228: 'S',
#  229: 'PR',
#  230: 'S',
#  231: 'A',
#  232: 'V',
#  233: 'ADV',
#  234: 'CONJ',
#  235: '-',
#  236: 'A',
#  237: 'V',
#  238: 'PR',
#  239: '-',
#  240: 'S',
#  241: 'A',
#  242: 'S',
#  243: 'CONJ',
#  244: 'PR',
#  245: 'A',
#  246: 'V',
#  247: 'V',
#  248: 'ADV',
#  249: 'A',
#  250: 'V',
#  251: 'S',
#  252: 'S',
#  253: 'PR',
#  254: 'S',
#  255: 'S',
#  256: 'PR',
#  257: 'A',
#  258: 'S'}

# %% [markdown]
# Длина совпадает с длиной размеченных токенов

# %%
len(pymorphy_tagged)
# Out:
# 259

# %% [markdown]
# ## 2.2. mystem

# %%
from pymystem3 import Mystem

# %% [markdown]
# Создаю словарь-конвертер

# %%
mystem_conv = {
    'A': 'A',
    'ADV': 'ADV',
    'ADVPRO': 'ADV',
    'ANUM': '-',
    'APRO': '-',
    'COM': '-',
    'CONJ': 'CONJ',
    'INTJ': 'ADV',
    'NUM': '-',
    'PART': 'ADV',
    'PR': 'PR',
    'S': 'S',
    'SPRO': '-',
    'V': 'V'
}

# %%
s = Mystem()

# %% [raw]
# Анализирус с помощью mystem, при этом не токенизирую, так как у него есть встроенный токенизатор

# %%
mystem_tagged = {}
i = 0
for text in corpus:
    for word in s.analyze(text):
        if word['text'].isalpha():    
            pos = word['analysis'][0]['gr'].split(',')[0].split('=')[0]
            mystem_tagged[i] = {'tag': mystem_conv[pos], 'word': word['text']}
            i += 1

# %%
mystem_tagged
# Out:
# {0: {'tag': 'ADV', 'word': 'Не'},
#  1: {'tag': 'ADV', 'word': 'прилично'},
#  2: {'tag': 'ADV', 'word': 'ли'},
#  3: {'tag': 'V', 'word': 'будет'},
#  4: {'tag': '-', 'word': 'нам'},
#  5: {'tag': 'S', 'word': 'братия'},
#  6: {'tag': 'V', 'word': 'Начать'},
#  7: {'tag': 'A', 'word': 'древним'},
#  8: {'tag': 'S', 'word': 'складом'},
#  9: {'tag': 'A', 'word': 'Печальную'},
#  10: {'tag': 'S', 'word': 'повесть'},
#  11: {'tag': 'PR', 'word': 'о'},
#  12: {'tag': 'S', 'word': 'битвах'},
#  13: {'tag': 'S', 'word': 'Игоря'},
#  14: {'tag': 'S', 'word': 'Игоря'},
#  15: {'tag': 'S', 'word': 'Святославича'},
#  16: {'tag': 'V', 'word': 'Начаться'},
#  17: {'tag': 'ADV', 'word': 'же'},
#  18: {'tag': '-', 'word': 'сей'},
#  19: {'tag': 'S', 'word': 'песни'},
#  20: {'tag': 'PR', 'word': 'По'},
#  21: {'tag': 'S', 'word': 'былинам'},
#  22: {'tag': '-', 'word': 'сего'},
#  23: {'tag': 'S', 'word': 'времени'},
#  24: {'tag': 'CONJ', 'word': 'А'},
#  25: {'tag': 'ADV', 'word': 'не'},
#  26: {'tag': 'PR', 'word': 'по'},
#  27: {'tag': 'S', 'word': 'вымыслам'},
#  28: {'tag': 'S', 'word': 'Бояновым'},
#  29: {'tag': 'A', 'word': 'Вещий'},
#  30: {'tag': 'S', 'word': 'Боян'},
#  31: {'tag': 'CONJ', 'word': 'Если'},
#  32: {'tag': 'S', 'word': 'песнь'},
#  33: {'tag': '-', 'word': 'кому'},
#  34: {'tag': 'V', 'word': 'сотворить'},
#  35: {'tag': 'V', 'word': 'хотел'},
#  36: {'tag': 'V', 'word': 'Растекался'},
#  37: {'tag': 'S', 'word': 'мыслию'},
#  38: {'tag': 'PR', 'word': 'по'},
#  39: {'tag': 'S', 'word': 'древу'},
#  40: {'tag': 'A', 'word': 'Серым'},
#  41: {'tag': 'S', 'word': 'волком'},
#  42: {'tag': 'PR', 'word': 'по'},
#  43: {'tag': 'S', 'word': 'земли'},
#  44: {'tag': 'A', 'word': 'Сизым'},
#  45: {'tag': 'S', 'word': 'орлом'},
#  46: {'tag': 'PR', 'word': 'под'},
#  47: {'tag': 'S', 'word': 'облаками'},
#  48: {'tag': '-', 'word': 'Вашу'},
#  49: {'tag': 'S', 'word': 'мысль'},
#  50: {'tag': 'V', 'word': 'мечтающую'},
#  51: {'tag': 'PR', 'word': 'на'},
#  52: {'tag': 'V', 'word': 'размягченном'},
#  53: {'tag': 'S', 'word': 'мозгу'},
#  54: {'tag': 'CONJ', 'word': 'как'},
#  55: {'tag': 'V', 'word': 'выжиревший'},
#  56: {'tag': 'S', 'word': 'лакей'},
#  57: {'tag': 'PR', 'word': 'на'},
#  58: {'tag': 'A', 'word': 'засаленной'},
#  59: {'tag': 'S', 'word': 'кушетке'},
#  60: {'tag': 'V', 'word': 'буду'},
#  61: {'tag': 'V', 'word': 'дразнить'},
#  62: {'tag': 'PR', 'word': 'об'},
#  63: {'tag': 'A', 'word': 'окровавленный'},
#  64: {'tag': 'S', 'word': 'сердца'},
#  65: {'tag': 'S', 'word': 'лоскут'},
#  66: {'tag': 'ADV', 'word': 'досыта'},
#  67: {'tag': 'V', 'word': 'изъиздеваюсь'},
#  68: {'tag': 'A', 'word': 'нахальный'},
#  69: {'tag': 'CONJ', 'word': 'и'},
#  70: {'tag': 'A', 'word': 'едкий'},
#  71: {'tag': 'PR', 'word': 'У'},
#  72: {'tag': '-', 'word': 'меня'},
#  73: {'tag': 'PR', 'word': 'в'},
#  74: {'tag': 'S', 'word': 'душе'},
#  75: {'tag': 'ADV', 'word': 'ни'},
#  76: {'tag': '-', 'word': 'одного'},
#  77: {'tag': 'A', 'word': 'седого'},
#  78: {'tag': 'S', 'word': 'волоса'},
#  79: {'tag': 'CONJ', 'word': 'и'},
#  80: {'tag': 'A', 'word': 'старческой'},
#  81: {'tag': 'S', 'word': 'нежности'},
#  82: {'tag': 'ADV', 'word': 'нет'},
#  83: {'tag': 'PR', 'word': 'в'},
#  84: {'tag': '-', 'word': 'ней'},
#  85: {'tag': 'S', 'word': 'Мир'},
#  86: {'tag': 'V', 'word': 'огромив'},
#  87: {'tag': 'S', 'word': 'мощью'},
#  88: {'tag': 'S', 'word': 'голоса'},
#  89: {'tag': 'V', 'word': 'иду'},
#  90: {'tag': 'A', 'word': 'красивый'},
#  91: {'tag': 'A', 'word': 'двадцатидвухлетний'},
#  92: {'tag': 'A', 'word': 'Нежные'},
#  93: {'tag': '-', 'word': 'Вы'},
#  94: {'tag': 'S', 'word': 'любовь'},
#  95: {'tag': 'PR', 'word': 'на'},
#  96: {'tag': 'S', 'word': 'скрипки'},
#  97: {'tag': 'V', 'word': 'ложите'},
#  98: {'tag': 'S', 'word': 'Любовь'},
#  99: {'tag': 'PR', 'word': 'на'},
#  100: {'tag': 'S', 'word': 'литавры'},
#  101: {'tag': 'V', 'word': 'ложит'},
#  102: {'tag': 'A', 'word': 'грубый'},
#  103: {'tag': 'CONJ', 'word': 'А'},
#  104: {'tag': '-', 'word': 'себя'},
#  105: {'tag': 'CONJ', 'word': 'как'},
#  106: {'tag': '-', 'word': 'я'},
#  107: {'tag': 'V', 'word': 'вывернуть'},
#  108: {'tag': 'ADV', 'word': 'не'},
#  109: {'tag': 'V', 'word': 'можете'},
#  110: {'tag': 'CONJ', 'word': 'чтобы'},
#  111: {'tag': 'V', 'word': 'были'},
#  112: {'tag': '-', 'word': 'одни'},
#  113: {'tag': 'A', 'word': 'сплошные'},
#  114: {'tag': 'S', 'word': 'губы'},
#  115: {'tag': 'V', 'word': 'Приходите'},
#  116: {'tag': 'V', 'word': 'учиться'},
#  117: {'tag': 'PR', 'word': 'из'},
#  118: {'tag': 'S', 'word': 'гостиной'},
#  119: {'tag': 'A', 'word': 'батистовая'},
#  120: {'tag': 'A', 'word': 'чинная'},
#  121: {'tag': 'S', 'word': 'чиновница'},
#  122: {'tag': 'A', 'word': 'ангельской'},
#  123: {'tag': 'S', 'word': 'лиги'},
#  124: {'tag': 'A', 'word': 'Низкий'},
#  125: {'tag': 'S', 'word': 'дом'},
#  126: {'tag': 'PR', 'word': 'без'},
#  127: {'tag': '-', 'word': 'меня'},
#  128: {'tag': 'V', 'word': 'ссутулится'},
#  129: {'tag': 'A', 'word': 'Старый'},
#  130: {'tag': 'S', 'word': 'пёс'},
#  131: {'tag': '-', 'word': 'мой'},
#  132: {'tag': 'ADV', 'word': 'давно'},
#  133: {'tag': 'V', 'word': 'издох'},
#  134: {'tag': 'PR', 'word': 'На'},
#  135: {'tag': 'A', 'word': 'московских'},
#  136: {'tag': 'A', 'word': 'изогнутых'},
#  137: {'tag': 'S', 'word': 'улицах'},
#  138: {'tag': 'V', 'word': 'Умереть'},
#  139: {'tag': 'V', 'word': 'знать'},
#  140: {'tag': 'V', 'word': 'сулил'},
#  141: {'tag': '-', 'word': 'мне'},
#  142: {'tag': 'S', 'word': 'Бог'},
#  143: {'tag': '-', 'word': 'Я'},
#  144: {'tag': 'V', 'word': 'люблю'},
#  145: {'tag': '-', 'word': 'этот'},
#  146: {'tag': 'S', 'word': 'город'},
#  147: {'tag': 'A', 'word': 'вязевый'},
#  148: {'tag': 'CONJ', 'word': 'Пусть'},
#  149: {'tag': 'V', 'word': 'обрюзг'},
#  150: {'tag': '-', 'word': 'он'},
#  151: {'tag': 'CONJ', 'word': 'и'},
#  152: {'tag': 'ADV', 'word': 'пусть'},
#  153: {'tag': 'V', 'word': 'одрях'},
#  154: {'tag': 'A', 'word': 'Золотая'},
#  155: {'tag': 'A', 'word': 'дремотная'},
#  156: {'tag': 'S', 'word': 'Азия'},
#  157: {'tag': 'V', 'word': 'Опочила'},
#  158: {'tag': 'PR', 'word': 'на'},
#  159: {'tag': 'S', 'word': 'куполах'},
#  160: {'tag': 'CONJ', 'word': 'А'},
#  161: {'tag': 'CONJ', 'word': 'когда'},
#  162: {'tag': 'S', 'word': 'ночью'},
#  163: {'tag': 'V', 'word': 'светит'},
#  164: {'tag': 'S', 'word': 'месяц'},
#  165: {'tag': 'CONJ', 'word': 'Когда'},
#  166: {'tag': 'V', 'word': 'светит'},
#  167: {'tag': 'S', 'word': 'чёрт'},
#  168: {'tag': 'V', 'word': 'знает'},
#  169: {'tag': 'ADV', 'word': 'как'},
#  170: {'tag': '-', 'word': 'Я'},
#  171: {'tag': 'V', 'word': 'иду'},
#  172: {'tag': 'S', 'word': 'головою'},
#  173: {'tag': 'V', 'word': 'свесясь'},
#  174: {'tag': 'S', 'word': 'Переулком'},
#  175: {'tag': 'PR', 'word': 'в'},
#  176: {'tag': 'A', 'word': 'знакомый'},
#  177: {'tag': 'S', 'word': 'кабак'},
#  178: {'tag': 'S', 'word': 'Шум'},
#  179: {'tag': 'CONJ', 'word': 'и'},
#  180: {'tag': 'S', 'word': 'гам'},
#  181: {'tag': 'PR', 'word': 'в'},
#  182: {'tag': '-', 'word': 'этом'},
#  183: {'tag': 'S', 'word': 'логове'},
#  184: {'tag': 'A', 'word': 'жутком'},
#  185: {'tag': 'CONJ', 'word': 'Но'},
#  186: {'tag': '-', 'word': 'всю'},
#  187: {'tag': 'S', 'word': 'ночь'},
#  188: {'tag': 'ADV', 'word': 'напролёт'},
#  189: {'tag': 'PR', 'word': 'до'},
#  190: {'tag': 'S', 'word': 'зари'},
#  191: {'tag': '-', 'word': 'Я'},
#  192: {'tag': 'V', 'word': 'читаю'},
#  193: {'tag': 'S', 'word': 'стихи'},
#  194: {'tag': 'S', 'word': 'проституткам'},
#  195: {'tag': 'CONJ', 'word': 'И'},
#  196: {'tag': 'PR', 'word': 'с'},
#  197: {'tag': 'S', 'word': 'бандитами'},
#  198: {'tag': 'V', 'word': 'жарю'},
#  199: {'tag': 'S', 'word': 'спирт'},
#  200: {'tag': 'A', 'word': 'Седое'},
#  201: {'tag': 'PR', 'word': 'в'},
#  202: {'tag': 'S', 'word': 'джинсах'},
#  203: {'tag': 'PR', 'word': 'от'},
#  204: {'tag': 'S', 'word': 'кутюр'},
#  205: {'tag': 'S', 'word': 'Абсурд'},
#  206: {'tag': 'S', 'word': 'карикатура'},
#  207: {'tag': 'ADV', 'word': 'Смешно'},
#  208: {'tag': 'PR', 'word': 'в'},
#  209: {'tag': 'S', 'word': 'стране'},
#  210: {'tag': 'S', 'word': 'мультикультур'},
#  211: {'tag': 'V', 'word': 'Закончилась'},
#  212: {'tag': 'S', 'word': 'культура'},
#  213: {'tag': 'CONJ', 'word': 'И'},
#  214: {'tag': 'S', 'word': 'свет'},
#  215: {'tag': 'V', 'word': 'погас'},
#  216: {'tag': 'CONJ', 'word': 'и'},
#  217: {'tag': 'S', 'word': 'гроб'},
#  218: {'tag': 'A', 'word': 'готов'},
#  219: {'tag': 'CONJ', 'word': 'И'},
#  220: {'tag': '-', 'word': 'мне'},
#  221: {'tag': 'S', 'word': 'клауд'},
#  222: {'tag': 'ADV', 'word': 'грустно'},
#  223: {'tag': 'PR', 'word': 'В'},
#  224: {'tag': 'S', 'word': 'стране'},
#  225: {'tag': 'A', 'word': 'есенинских'},
#  226: {'tag': 'S', 'word': 'стихов'},
#  227: {'tag': 'V', 'word': 'Закончилось'},
#  228: {'tag': 'S', 'word': 'искусство'},
#  229: {'tag': 'S', 'word': 'Рояльчик'},
#  230: {'tag': 'PR', 'word': 'в'},
#  231: {'tag': 'S', 'word': 'парке'},
#  232: {'tag': 'A', 'word': 'городском'},
#  233: {'tag': 'V', 'word': 'Расстроен'},
#  234: {'tag': 'ADV', 'word': 'очень'},
#  235: {'tag': 'ADV', 'word': 'очень'},
#  236: {'tag': 'CONJ', 'word': 'И'},
#  237: {'tag': 'A', 'word': 'страшный'},
#  238: {'tag': 'V', 'word': 'жмёт'},
#  239: {'tag': 'PR', 'word': 'на'},
#  240: {'tag': '-', 'word': 'нём'},
#  241: {'tag': 'S', 'word': 'Бемоль'},
#  242: {'tag': 'A', 'word': 'чернее'},
#  243: {'tag': 'S', 'word': 'ночи'},
#  244: {'tag': 'CONJ', 'word': 'И'},
#  245: {'tag': 'PR', 'word': 'в'},
#  246: {'tag': 'A', 'word': 'чёрном'},
#  247: {'tag': 'V', 'word': 'худи'},
#  248: {'tag': 'V', 'word': 'бродит'},
#  249: {'tag': 'ADV', 'word': 'там'},
#  250: {'tag': 'A', 'word': 'Провинциальный'},
#  251: {'tag': 'S', 'word': 'Бэнкси'},
#  252: {'tag': 'S', 'word': 'Баллоном'},
#  253: {'tag': 'S', 'word': 'строчки'},
#  254: {'tag': 'PR', 'word': 'по'},
#  255: {'tag': 'S', 'word': 'углам'},
#  256: {'tag': 'S', 'word': 'Слова'},
#  257: {'tag': 'PR', 'word': 'из'},
#  258: {'tag': '-', 'word': 'этой'},
#  259: {'tag': 'S', 'word': 'песни'}}

# %% [markdown]
# Длина полученного словаря получилась больше, чем размеченного вручную, нужно убрать один токен

# %%
len(mystem_tagged)
# Out:
# 260

# %% [markdown]
# Оеазывается, он разбил "клауд-грустно" на два токена. Я решил выкинуть часть "клауд"

# %%
mystem_tagged.pop(221)
# Out:
# {'tag': 'S', 'word': 'клауд'}

# %% [markdown]
# Изменяю индексы токенов, чтобы они сошлись

# %%
for i in range(221, 259):
    mystem_tagged[i] = mystem_tagged[i+1]

# %% [markdown]
# Последний токен теперь дублируется, выкидываю его

# %%
mystem_tagged.pop(259)
# Out:
# {'tag': 'S', 'word': 'песни'}

# %% [markdown]
# Теперь размеры совпадают

# %%
mystem_tagged
# Out:
# {0: {'tag': 'ADV', 'word': 'Не'},
#  1: {'tag': 'ADV', 'word': 'прилично'},
#  2: {'tag': 'ADV', 'word': 'ли'},
#  3: {'tag': 'V', 'word': 'будет'},
#  4: {'tag': '-', 'word': 'нам'},
#  5: {'tag': 'S', 'word': 'братия'},
#  6: {'tag': 'V', 'word': 'Начать'},
#  7: {'tag': 'A', 'word': 'древним'},
#  8: {'tag': 'S', 'word': 'складом'},
#  9: {'tag': 'A', 'word': 'Печальную'},
#  10: {'tag': 'S', 'word': 'повесть'},
#  11: {'tag': 'PR', 'word': 'о'},
#  12: {'tag': 'S', 'word': 'битвах'},
#  13: {'tag': 'S', 'word': 'Игоря'},
#  14: {'tag': 'S', 'word': 'Игоря'},
#  15: {'tag': 'S', 'word': 'Святославича'},
#  16: {'tag': 'V', 'word': 'Начаться'},
#  17: {'tag': 'ADV', 'word': 'же'},
#  18: {'tag': '-', 'word': 'сей'},
#  19: {'tag': 'S', 'word': 'песни'},
#  20: {'tag': 'PR', 'word': 'По'},
#  21: {'tag': 'S', 'word': 'былинам'},
#  22: {'tag': '-', 'word': 'сего'},
#  23: {'tag': 'S', 'word': 'времени'},
#  24: {'tag': 'CONJ', 'word': 'А'},
#  25: {'tag': 'ADV', 'word': 'не'},
#  26: {'tag': 'PR', 'word': 'по'},
#  27: {'tag': 'S', 'word': 'вымыслам'},
#  28: {'tag': 'S', 'word': 'Бояновым'},
#  29: {'tag': 'A', 'word': 'Вещий'},
#  30: {'tag': 'S', 'word': 'Боян'},
#  31: {'tag': 'CONJ', 'word': 'Если'},
#  32: {'tag': 'S', 'word': 'песнь'},
#  33: {'tag': '-', 'word': 'кому'},
#  34: {'tag': 'V', 'word': 'сотворить'},
#  35: {'tag': 'V', 'word': 'хотел'},
#  36: {'tag': 'V', 'word': 'Растекался'},
#  37: {'tag': 'S', 'word': 'мыслию'},
#  38: {'tag': 'PR', 'word': 'по'},
#  39: {'tag': 'S', 'word': 'древу'},
#  40: {'tag': 'A', 'word': 'Серым'},
#  41: {'tag': 'S', 'word': 'волком'},
#  42: {'tag': 'PR', 'word': 'по'},
#  43: {'tag': 'S', 'word': 'земли'},
#  44: {'tag': 'A', 'word': 'Сизым'},
#  45: {'tag': 'S', 'word': 'орлом'},
#  46: {'tag': 'PR', 'word': 'под'},
#  47: {'tag': 'S', 'word': 'облаками'},
#  48: {'tag': '-', 'word': 'Вашу'},
#  49: {'tag': 'S', 'word': 'мысль'},
#  50: {'tag': 'V', 'word': 'мечтающую'},
#  51: {'tag': 'PR', 'word': 'на'},
#  52: {'tag': 'V', 'word': 'размягченном'},
#  53: {'tag': 'S', 'word': 'мозгу'},
#  54: {'tag': 'CONJ', 'word': 'как'},
#  55: {'tag': 'V', 'word': 'выжиревший'},
#  56: {'tag': 'S', 'word': 'лакей'},
#  57: {'tag': 'PR', 'word': 'на'},
#  58: {'tag': 'A', 'word': 'засаленной'},
#  59: {'tag': 'S', 'word': 'кушетке'},
#  60: {'tag': 'V', 'word': 'буду'},
#  61: {'tag': 'V', 'word': 'дразнить'},
#  62: {'tag': 'PR', 'word': 'об'},
#  63: {'tag': 'A', 'word': 'окровавленный'},
#  64: {'tag': 'S', 'word': 'сердца'},
#  65: {'tag': 'S', 'word': 'лоскут'},
#  66: {'tag': 'ADV', 'word': 'досыта'},
#  67: {'tag': 'V', 'word': 'изъиздеваюсь'},
#  68: {'tag': 'A', 'word': 'нахальный'},
#  69: {'tag': 'CONJ', 'word': 'и'},
#  70: {'tag': 'A', 'word': 'едкий'},
#  71: {'tag': 'PR', 'word': 'У'},
#  72: {'tag': '-', 'word': 'меня'},
#  73: {'tag': 'PR', 'word': 'в'},
#  74: {'tag': 'S', 'word': 'душе'},
#  75: {'tag': 'ADV', 'word': 'ни'},
#  76: {'tag': '-', 'word': 'одного'},
#  77: {'tag': 'A', 'word': 'седого'},
#  78: {'tag': 'S', 'word': 'волоса'},
#  79: {'tag': 'CONJ', 'word': 'и'},
#  80: {'tag': 'A', 'word': 'старческой'},
#  81: {'tag': 'S', 'word': 'нежности'},
#  82: {'tag': 'ADV', 'word': 'нет'},
#  83: {'tag': 'PR', 'word': 'в'},
#  84: {'tag': '-', 'word': 'ней'},
#  85: {'tag': 'S', 'word': 'Мир'},
#  86: {'tag': 'V', 'word': 'огромив'},
#  87: {'tag': 'S', 'word': 'мощью'},
#  88: {'tag': 'S', 'word': 'голоса'},
#  89: {'tag': 'V', 'word': 'иду'},
#  90: {'tag': 'A', 'word': 'красивый'},
#  91: {'tag': 'A', 'word': 'двадцатидвухлетний'},
#  92: {'tag': 'A', 'word': 'Нежные'},
#  93: {'tag': '-', 'word': 'Вы'},
#  94: {'tag': 'S', 'word': 'любовь'},
#  95: {'tag': 'PR', 'word': 'на'},
#  96: {'tag': 'S', 'word': 'скрипки'},
#  97: {'tag': 'V', 'word': 'ложите'},
#  98: {'tag': 'S', 'word': 'Любовь'},
#  99: {'tag': 'PR', 'word': 'на'},
#  100: {'tag': 'S', 'word': 'литавры'},
#  101: {'tag': 'V', 'word': 'ложит'},
#  102: {'tag': 'A', 'word': 'грубый'},
#  103: {'tag': 'CONJ', 'word': 'А'},
#  104: {'tag': '-', 'word': 'себя'},
#  105: {'tag': 'CONJ', 'word': 'как'},
#  106: {'tag': '-', 'word': 'я'},
#  107: {'tag': 'V', 'word': 'вывернуть'},
#  108: {'tag': 'ADV', 'word': 'не'},
#  109: {'tag': 'V', 'word': 'можете'},
#  110: {'tag': 'CONJ', 'word': 'чтобы'},
#  111: {'tag': 'V', 'word': 'были'},
#  112: {'tag': '-', 'word': 'одни'},
#  113: {'tag': 'A', 'word': 'сплошные'},
#  114: {'tag': 'S', 'word': 'губы'},
#  115: {'tag': 'V', 'word': 'Приходите'},
#  116: {'tag': 'V', 'word': 'учиться'},
#  117: {'tag': 'PR', 'word': 'из'},
#  118: {'tag': 'S', 'word': 'гостиной'},
#  119: {'tag': 'A', 'word': 'батистовая'},
#  120: {'tag': 'A', 'word': 'чинная'},
#  121: {'tag': 'S', 'word': 'чиновница'},
#  122: {'tag': 'A', 'word': 'ангельской'},
#  123: {'tag': 'S', 'word': 'лиги'},
#  124: {'tag': 'A', 'word': 'Низкий'},
#  125: {'tag': 'S', 'word': 'дом'},
#  126: {'tag': 'PR', 'word': 'без'},
#  127: {'tag': '-', 'word': 'меня'},
#  128: {'tag': 'V', 'word': 'ссутулится'},
#  129: {'tag': 'A', 'word': 'Старый'},
#  130: {'tag': 'S', 'word': 'пёс'},
#  131: {'tag': '-', 'word': 'мой'},
#  132: {'tag': 'ADV', 'word': 'давно'},
#  133: {'tag': 'V', 'word': 'издох'},
#  134: {'tag': 'PR', 'word': 'На'},
#  135: {'tag': 'A', 'word': 'московских'},
#  136: {'tag': 'A', 'word': 'изогнутых'},
#  137: {'tag': 'S', 'word': 'улицах'},
#  138: {'tag': 'V', 'word': 'Умереть'},
#  139: {'tag': 'V', 'word': 'знать'},
#  140: {'tag': 'V', 'word': 'сулил'},
#  141: {'tag': '-', 'word': 'мне'},
#  142: {'tag': 'S', 'word': 'Бог'},
#  143: {'tag': '-', 'word': 'Я'},
#  144: {'tag': 'V', 'word': 'люблю'},
#  145: {'tag': '-', 'word': 'этот'},
#  146: {'tag': 'S', 'word': 'город'},
#  147: {'tag': 'A', 'word': 'вязевый'},
#  148: {'tag': 'CONJ', 'word': 'Пусть'},
#  149: {'tag': 'V', 'word': 'обрюзг'},
#  150: {'tag': '-', 'word': 'он'},
#  151: {'tag': 'CONJ', 'word': 'и'},
#  152: {'tag': 'ADV', 'word': 'пусть'},
#  153: {'tag': 'V', 'word': 'одрях'},
#  154: {'tag': 'A', 'word': 'Золотая'},
#  155: {'tag': 'A', 'word': 'дремотная'},
#  156: {'tag': 'S', 'word': 'Азия'},
#  157: {'tag': 'V', 'word': 'Опочила'},
#  158: {'tag': 'PR', 'word': 'на'},
#  159: {'tag': 'S', 'word': 'куполах'},
#  160: {'tag': 'CONJ', 'word': 'А'},
#  161: {'tag': 'CONJ', 'word': 'когда'},
#  162: {'tag': 'S', 'word': 'ночью'},
#  163: {'tag': 'V', 'word': 'светит'},
#  164: {'tag': 'S', 'word': 'месяц'},
#  165: {'tag': 'CONJ', 'word': 'Когда'},
#  166: {'tag': 'V', 'word': 'светит'},
#  167: {'tag': 'S', 'word': 'чёрт'},
#  168: {'tag': 'V', 'word': 'знает'},
#  169: {'tag': 'ADV', 'word': 'как'},
#  170: {'tag': '-', 'word': 'Я'},
#  171: {'tag': 'V', 'word': 'иду'},
#  172: {'tag': 'S', 'word': 'головою'},
#  173: {'tag': 'V', 'word': 'свесясь'},
#  174: {'tag': 'S', 'word': 'Переулком'},
#  175: {'tag': 'PR', 'word': 'в'},
#  176: {'tag': 'A', 'word': 'знакомый'},
#  177: {'tag': 'S', 'word': 'кабак'},
#  178: {'tag': 'S', 'word': 'Шум'},
#  179: {'tag': 'CONJ', 'word': 'и'},
#  180: {'tag': 'S', 'word': 'гам'},
#  181: {'tag': 'PR', 'word': 'в'},
#  182: {'tag': '-', 'word': 'этом'},
#  183: {'tag': 'S', 'word': 'логове'},
#  184: {'tag': 'A', 'word': 'жутком'},
#  185: {'tag': 'CONJ', 'word': 'Но'},
#  186: {'tag': '-', 'word': 'всю'},
#  187: {'tag': 'S', 'word': 'ночь'},
#  188: {'tag': 'ADV', 'word': 'напролёт'},
#  189: {'tag': 'PR', 'word': 'до'},
#  190: {'tag': 'S', 'word': 'зари'},
#  191: {'tag': '-', 'word': 'Я'},
#  192: {'tag': 'V', 'word': 'читаю'},
#  193: {'tag': 'S', 'word': 'стихи'},
#  194: {'tag': 'S', 'word': 'проституткам'},
#  195: {'tag': 'CONJ', 'word': 'И'},
#  196: {'tag': 'PR', 'word': 'с'},
#  197: {'tag': 'S', 'word': 'бандитами'},
#  198: {'tag': 'V', 'word': 'жарю'},
#  199: {'tag': 'S', 'word': 'спирт'},
#  200: {'tag': 'A', 'word': 'Седое'},
#  201: {'tag': 'PR', 'word': 'в'},
#  202: {'tag': 'S', 'word': 'джинсах'},
#  203: {'tag': 'PR', 'word': 'от'},
#  204: {'tag': 'S', 'word': 'кутюр'},
#  205: {'tag': 'S', 'word': 'Абсурд'},
#  206: {'tag': 'S', 'word': 'карикатура'},
#  207: {'tag': 'ADV', 'word': 'Смешно'},
#  208: {'tag': 'PR', 'word': 'в'},
#  209: {'tag': 'S', 'word': 'стране'},
#  210: {'tag': 'S', 'word': 'мультикультур'},
#  211: {'tag': 'V', 'word': 'Закончилась'},
#  212: {'tag': 'S', 'word': 'культура'},
#  213: {'tag': 'CONJ', 'word': 'И'},
#  214: {'tag': 'S', 'word': 'свет'},
#  215: {'tag': 'V', 'word': 'погас'},
#  216: {'tag': 'CONJ', 'word': 'и'},
#  217: {'tag': 'S', 'word': 'гроб'},
#  218: {'tag': 'A', 'word': 'готов'},
#  219: {'tag': 'CONJ', 'word': 'И'},
#  220: {'tag': '-', 'word': 'мне'},
#  222: {'tag': 'PR', 'word': 'В'},
#  223: {'tag': 'S', 'word': 'стране'},
#  224: {'tag': 'A', 'word': 'есенинских'},
#  225: {'tag': 'S', 'word': 'стихов'},
#  226: {'tag': 'V', 'word': 'Закончилось'},
#  227: {'tag': 'S', 'word': 'искусство'},
#  228: {'tag': 'S', 'word': 'Рояльчик'},
#  229: {'tag': 'PR', 'word': 'в'},
#  230: {'tag': 'S', 'word': 'парке'},
#  231: {'tag': 'A', 'word': 'городском'},
#  232: {'tag': 'V', 'word': 'Расстроен'},
#  233: {'tag': 'ADV', 'word': 'очень'},
#  234: {'tag': 'ADV', 'word': 'очень'},
#  235: {'tag': 'CONJ', 'word': 'И'},
#  236: {'tag': 'A', 'word': 'страшный'},
#  237: {'tag': 'V', 'word': 'жмёт'},
#  238: {'tag': 'PR', 'word': 'на'},
#  239: {'tag': '-', 'word': 'нём'},
#  240: {'tag': 'S', 'word': 'Бемоль'},
#  241: {'tag': 'A', 'word': 'чернее'},
#  242: {'tag': 'S', 'word': 'ночи'},
#  243: {'tag': 'CONJ', 'word': 'И'},
#  244: {'tag': 'PR', 'word': 'в'},
#  245: {'tag': 'A', 'word': 'чёрном'},
#  246: {'tag': 'V', 'word': 'худи'},
#  247: {'tag': 'V', 'word': 'бродит'},
#  248: {'tag': 'ADV', 'word': 'там'},
#  249: {'tag': 'A', 'word': 'Провинциальный'},
#  250: {'tag': 'S', 'word': 'Бэнкси'},
#  251: {'tag': 'S', 'word': 'Баллоном'},
#  252: {'tag': 'S', 'word': 'строчки'},
#  253: {'tag': 'PR', 'word': 'по'},
#  254: {'tag': 'S', 'word': 'углам'},
#  255: {'tag': 'S', 'word': 'Слова'},
#  256: {'tag': 'PR', 'word': 'из'},
#  257: {'tag': '-', 'word': 'этой'},
#  258: {'tag': 'S', 'word': 'песни'},
#  221: {'tag': 'ADV', 'word': 'грустно'}}

# %% [markdown]
# # 2.3. spacy

# %%
import spacy
nlp = spacy.load("ru_core_news_lg")

# %% [markdown]
# Создаю словарь-конвертер

# %%
spacy_conv = {
    'ADJ': 'A',
    'ADP': 'PR',
    'ADV': 'ADV',
    'AUX': 'V',
    'CCONJ': 'CONJ',
    'DET': '-',
    'INTJ': 'ADV',
    'NOUN': 'S',
    'NUM': '-',
    'PART': 'ADV',
    'PRON': '-',
    'PROPN': 'S',
    'PUNCT': '-',
    'SCONJ': 'CONJ',
    'SYM': '-',
    'VERB': 'V',
    'X': '-'
}

# %% [markdown]
# Здесь также не провожу токенизации из-за наличия встроенного токенизатора

# %%
spacy_tagged = {}
i = 0
for text in corpus:
    for word in nlp(text):
        if word.text.isalpha(): 
            spacy_tagged[i] = {'tag': spacy_conv[word.pos_], 'word': word.text}
            i += 1

# %%
spacy_tagged
# Out:
# {0: {'tag': 'ADV', 'word': 'Не'},
#  1: {'tag': 'A', 'word': 'прилично'},
#  2: {'tag': 'ADV', 'word': 'ли'},
#  3: {'tag': 'V', 'word': 'будет'},
#  4: {'tag': '-', 'word': 'нам'},
#  5: {'tag': 'S', 'word': 'братия'},
#  6: {'tag': 'V', 'word': 'Начать'},
#  7: {'tag': 'A', 'word': 'древним'},
#  8: {'tag': 'S', 'word': 'складом'},
#  9: {'tag': 'A', 'word': 'Печальную'},
#  10: {'tag': 'S', 'word': 'повесть'},
#  11: {'tag': 'PR', 'word': 'о'},
#  12: {'tag': 'S', 'word': 'битвах'},
#  13: {'tag': 'S', 'word': 'Игоря'},
#  14: {'tag': 'S', 'word': 'Игоря'},
#  15: {'tag': 'S', 'word': 'Святославича'},
#  16: {'tag': 'V', 'word': 'Начаться'},
#  17: {'tag': 'ADV', 'word': 'же'},
#  18: {'tag': '-', 'word': 'сей'},
#  19: {'tag': 'S', 'word': 'песни'},
#  20: {'tag': 'PR', 'word': 'По'},
#  21: {'tag': 'S', 'word': 'былинам'},
#  22: {'tag': '-', 'word': 'сего'},
#  23: {'tag': 'S', 'word': 'времени'},
#  24: {'tag': 'CONJ', 'word': 'А'},
#  25: {'tag': 'ADV', 'word': 'не'},
#  26: {'tag': 'PR', 'word': 'по'},
#  27: {'tag': 'S', 'word': 'вымыслам'},
#  28: {'tag': 'S', 'word': 'Бояновым'},
#  29: {'tag': 'V', 'word': 'Вещий'},
#  30: {'tag': 'S', 'word': 'Боян'},
#  31: {'tag': 'CONJ', 'word': 'Если'},
#  32: {'tag': 'S', 'word': 'песнь'},
#  33: {'tag': '-', 'word': 'кому'},
#  34: {'tag': 'V', 'word': 'сотворить'},
#  35: {'tag': 'V', 'word': 'хотел'},
#  36: {'tag': 'V', 'word': 'Растекался'},
#  37: {'tag': 'S', 'word': 'мыслию'},
#  38: {'tag': 'PR', 'word': 'по'},
#  39: {'tag': 'S', 'word': 'древу'},
#  40: {'tag': 'A', 'word': 'Серым'},
#  41: {'tag': 'S', 'word': 'волком'},
#  42: {'tag': 'PR', 'word': 'по'},
#  43: {'tag': 'S', 'word': 'земли'},
#  44: {'tag': 'A', 'word': 'Сизым'},
#  45: {'tag': 'S', 'word': 'орлом'},
#  46: {'tag': 'PR', 'word': 'под'},
#  47: {'tag': 'S', 'word': 'облаками'},
#  48: {'tag': '-', 'word': 'Вашу'},
#  49: {'tag': 'S', 'word': 'мысль'},
#  50: {'tag': 'V', 'word': 'мечтающую'},
#  51: {'tag': 'PR', 'word': 'на'},
#  52: {'tag': 'V', 'word': 'размягченном'},
#  53: {'tag': 'S', 'word': 'мозгу'},
#  54: {'tag': 'CONJ', 'word': 'как'},
#  55: {'tag': 'V', 'word': 'выжиревший'},
#  56: {'tag': 'S', 'word': 'лакей'},
#  57: {'tag': 'PR', 'word': 'на'},
#  58: {'tag': 'A', 'word': 'засаленной'},
#  59: {'tag': 'S', 'word': 'кушетке'},
#  60: {'tag': 'V', 'word': 'буду'},
#  61: {'tag': 'V', 'word': 'дразнить'},
#  62: {'tag': 'PR', 'word': 'об'},
#  63: {'tag': 'V', 'word': 'окровавленный'},
#  64: {'tag': 'S', 'word': 'сердца'},
#  65: {'tag': 'S', 'word': 'лоскут'},
#  66: {'tag': 'ADV', 'word': 'досыта'},
#  67: {'tag': 'V', 'word': 'изъиздеваюсь'},
#  68: {'tag': 'A', 'word': 'нахальный'},
#  69: {'tag': 'CONJ', 'word': 'и'},
#  70: {'tag': 'A', 'word': 'едкий'},
#  71: {'tag': 'PR', 'word': 'У'},
#  72: {'tag': '-', 'word': 'меня'},
#  73: {'tag': 'PR', 'word': 'в'},
#  74: {'tag': 'S', 'word': 'душе'},
#  75: {'tag': 'ADV', 'word': 'ни'},
#  76: {'tag': '-', 'word': 'одного'},
#  77: {'tag': 'A', 'word': 'седого'},
#  78: {'tag': 'S', 'word': 'волоса'},
#  79: {'tag': 'CONJ', 'word': 'и'},
#  80: {'tag': 'A', 'word': 'старческой'},
#  81: {'tag': 'S', 'word': 'нежности'},
#  82: {'tag': 'V', 'word': 'нет'},
#  83: {'tag': 'PR', 'word': 'в'},
#  84: {'tag': '-', 'word': 'ней'},
#  85: {'tag': 'S', 'word': 'Мир'},
#  86: {'tag': 'V', 'word': 'огромив'},
#  87: {'tag': 'S', 'word': 'мощью'},
#  88: {'tag': 'S', 'word': 'голоса'},
#  89: {'tag': 'V', 'word': 'иду'},
#  90: {'tag': 'A', 'word': 'красивый'},
#  91: {'tag': 'A', 'word': 'двадцатидвухлетний'},
#  92: {'tag': 'A', 'word': 'Нежные'},
#  93: {'tag': '-', 'word': 'Вы'},
#  94: {'tag': 'S', 'word': 'любовь'},
#  95: {'tag': 'PR', 'word': 'на'},
#  96: {'tag': 'S', 'word': 'скрипки'},
#  97: {'tag': 'V', 'word': 'ложите'},
#  98: {'tag': 'S', 'word': 'Любовь'},
#  99: {'tag': 'PR', 'word': 'на'},
#  100: {'tag': 'S', 'word': 'литавры'},
#  101: {'tag': 'V', 'word': 'ложит'},
#  102: {'tag': 'A', 'word': 'грубый'},
#  103: {'tag': 'CONJ', 'word': 'А'},
#  104: {'tag': '-', 'word': 'себя'},
#  105: {'tag': 'CONJ', 'word': 'как'},
#  106: {'tag': '-', 'word': 'я'},
#  107: {'tag': 'V', 'word': 'вывернуть'},
#  108: {'tag': 'ADV', 'word': 'не'},
#  109: {'tag': 'V', 'word': 'можете'},
#  110: {'tag': 'CONJ', 'word': 'чтобы'},
#  111: {'tag': 'V', 'word': 'были'},
#  112: {'tag': '-', 'word': 'одни'},
#  113: {'tag': 'A', 'word': 'сплошные'},
#  114: {'tag': 'S', 'word': 'губы'},
#  115: {'tag': 'V', 'word': 'Приходите'},
#  116: {'tag': 'V', 'word': 'учиться'},
#  117: {'tag': 'PR', 'word': 'из'},
#  118: {'tag': 'S', 'word': 'гостиной'},
#  119: {'tag': 'A', 'word': 'батистовая'},
#  120: {'tag': 'A', 'word': 'чинная'},
#  121: {'tag': 'S', 'word': 'чиновница'},
#  122: {'tag': 'A', 'word': 'ангельской'},
#  123: {'tag': 'S', 'word': 'лиги'},
#  124: {'tag': 'A', 'word': 'Низкий'},
#  125: {'tag': 'S', 'word': 'дом'},
#  126: {'tag': 'PR', 'word': 'без'},
#  127: {'tag': '-', 'word': 'меня'},
#  128: {'tag': 'V', 'word': 'ссутулится'},
#  129: {'tag': 'A', 'word': 'Старый'},
#  130: {'tag': 'A', 'word': 'пёс'},
#  131: {'tag': '-', 'word': 'мой'},
#  132: {'tag': 'ADV', 'word': 'давно'},
#  133: {'tag': 'V', 'word': 'издох'},
#  134: {'tag': 'PR', 'word': 'На'},
#  135: {'tag': 'A', 'word': 'московских'},
#  136: {'tag': 'V', 'word': 'изогнутых'},
#  137: {'tag': 'S', 'word': 'улицах'},
#  138: {'tag': 'V', 'word': 'Умереть'},
#  139: {'tag': 'V', 'word': 'знать'},
#  140: {'tag': 'V', 'word': 'сулил'},
#  141: {'tag': '-', 'word': 'мне'},
#  142: {'tag': 'S', 'word': 'Бог'},
#  143: {'tag': '-', 'word': 'Я'},
#  144: {'tag': 'V', 'word': 'люблю'},
#  145: {'tag': '-', 'word': 'этот'},
#  146: {'tag': 'S', 'word': 'город'},
#  147: {'tag': 'A', 'word': 'вязевый'},
#  148: {'tag': 'ADV', 'word': 'Пусть'},
#  149: {'tag': 'S', 'word': 'обрюзг'},
#  150: {'tag': '-', 'word': 'он'},
#  151: {'tag': 'CONJ', 'word': 'и'},
#  152: {'tag': 'ADV', 'word': 'пусть'},
#  153: {'tag': 'V', 'word': 'одрях'},
#  154: {'tag': 'A', 'word': 'Золотая'},
#  155: {'tag': 'A', 'word': 'дремотная'},
#  156: {'tag': 'S', 'word': 'Азия'},
#  157: {'tag': 'S', 'word': 'Опочила'},
#  158: {'tag': 'PR', 'word': 'на'},
#  159: {'tag': 'S', 'word': 'куполах'},
#  160: {'tag': 'CONJ', 'word': 'А'},
#  161: {'tag': 'CONJ', 'word': 'когда'},
#  162: {'tag': 'S', 'word': 'ночью'},
#  163: {'tag': 'V', 'word': 'светит'},
#  164: {'tag': 'S', 'word': 'месяц'},
#  165: {'tag': 'CONJ', 'word': 'Когда'},
#  166: {'tag': 'V', 'word': 'светит'},
#  167: {'tag': 'S', 'word': 'чёрт'},
#  168: {'tag': 'V', 'word': 'знает'},
#  169: {'tag': 'CONJ', 'word': 'как'},
#  170: {'tag': '-', 'word': 'Я'},
#  171: {'tag': 'V', 'word': 'иду'},
#  172: {'tag': 'S', 'word': 'головою'},
#  173: {'tag': 'V', 'word': 'свесясь'},
#  174: {'tag': 'A', 'word': 'Переулком'},
#  175: {'tag': 'PR', 'word': 'в'},
#  176: {'tag': 'A', 'word': 'знакомый'},
#  177: {'tag': 'S', 'word': 'кабак'},
#  178: {'tag': 'S', 'word': 'Шум'},
#  179: {'tag': 'CONJ', 'word': 'и'},
#  180: {'tag': 'S', 'word': 'гам'},
#  181: {'tag': 'PR', 'word': 'в'},
#  182: {'tag': '-', 'word': 'этом'},
#  183: {'tag': 'S', 'word': 'логове'},
#  184: {'tag': 'A', 'word': 'жутком'},
#  185: {'tag': 'CONJ', 'word': 'Но'},
#  186: {'tag': '-', 'word': 'всю'},
#  187: {'tag': 'S', 'word': 'ночь'},
#  188: {'tag': 'ADV', 'word': 'напролёт'},
#  189: {'tag': 'PR', 'word': 'до'},
#  190: {'tag': 'S', 'word': 'зари'},
#  191: {'tag': '-', 'word': 'Я'},
#  192: {'tag': 'V', 'word': 'читаю'},
#  193: {'tag': 'S', 'word': 'стихи'},
#  194: {'tag': 'S', 'word': 'проституткам'},
#  195: {'tag': 'CONJ', 'word': 'И'},
#  196: {'tag': 'PR', 'word': 'с'},
#  197: {'tag': 'S', 'word': 'бандитами'},
#  198: {'tag': 'V', 'word': 'жарю'},
#  199: {'tag': 'S', 'word': 'спирт'},
#  200: {'tag': 'S', 'word': 'Седое'},
#  201: {'tag': 'PR', 'word': 'в'},
#  202: {'tag': 'S', 'word': 'джинсах'},
#  203: {'tag': 'PR', 'word': 'от'},
#  204: {'tag': 'S', 'word': 'кутюр'},
#  205: {'tag': 'S', 'word': 'Абсурд'},
#  206: {'tag': 'S', 'word': 'карикатура'},
#  207: {'tag': 'S', 'word': 'Смешно'},
#  208: {'tag': 'PR', 'word': 'в'},
#  209: {'tag': 'S', 'word': 'стране'},
#  210: {'tag': 'S', 'word': 'мультикультур'},
#  211: {'tag': 'V', 'word': 'Закончилась'},
#  212: {'tag': 'S', 'word': 'культура'},
#  213: {'tag': 'CONJ', 'word': 'И'},
#  214: {'tag': 'S', 'word': 'свет'},
#  215: {'tag': 'V', 'word': 'погас'},
#  216: {'tag': 'CONJ', 'word': 'и'},
#  217: {'tag': 'S', 'word': 'гроб'},
#  218: {'tag': 'A', 'word': 'готов'},
#  219: {'tag': 'CONJ', 'word': 'И'},
#  220: {'tag': '-', 'word': 'мне'},
#  221: {'tag': 'ADV', 'word': 'клауд'},
#  222: {'tag': 'ADV', 'word': 'грустно'},
#  223: {'tag': 'PR', 'word': 'В'},
#  224: {'tag': 'S', 'word': 'стране'},
#  225: {'tag': 'A', 'word': 'есенинских'},
#  226: {'tag': 'S', 'word': 'стихов'},
#  227: {'tag': 'V', 'word': 'Закончилось'},
#  228: {'tag': 'S', 'word': 'искусство'},
#  229: {'tag': 'S', 'word': 'Рояльчик'},
#  230: {'tag': 'PR', 'word': 'в'},
#  231: {'tag': 'S', 'word': 'парке'},
#  232: {'tag': 'A', 'word': 'городском'},
#  233: {'tag': 'S', 'word': 'Расстроен'},
#  234: {'tag': 'ADV', 'word': 'очень'},
#  235: {'tag': 'ADV', 'word': 'очень'},
#  236: {'tag': 'CONJ', 'word': 'И'},
#  237: {'tag': '-', 'word': 'кто'},
#  238: {'tag': '-', 'word': 'то'},
#  239: {'tag': 'A', 'word': 'страшный'},
#  240: {'tag': 'S', 'word': 'жмёт'},
#  241: {'tag': 'PR', 'word': 'на'},
#  242: {'tag': 'S', 'word': 'нём'},
#  243: {'tag': 'S', 'word': 'Бемоль'},
#  244: {'tag': 'A', 'word': 'чернее'},
#  245: {'tag': 'S', 'word': 'ночи'},
#  246: {'tag': 'CONJ', 'word': 'И'},
#  247: {'tag': 'PR', 'word': 'в'},
#  248: {'tag': 'A', 'word': 'чёрном'},
#  249: {'tag': 'S', 'word': 'худи'},
#  250: {'tag': 'V', 'word': 'бродит'},
#  251: {'tag': 'ADV', 'word': 'там'},
#  252: {'tag': 'A', 'word': 'Провинциальный'},
#  253: {'tag': 'S', 'word': 'Бэнкси'},
#  254: {'tag': 'S', 'word': 'Баллоном'},
#  255: {'tag': 'S', 'word': 'строчки'},
#  256: {'tag': 'PR', 'word': 'по'},
#  257: {'tag': 'S', 'word': 'углам'},
#  258: {'tag': 'S', 'word': 'Слова'},
#  259: {'tag': 'PR', 'word': 'из'},
#  260: {'tag': '-', 'word': 'этой'},
#  261: {'tag': 'S', 'word': 'песни'}}

# %% [markdown]
# Получилось на 3 токена больше, чем в ручной разметке

# %%
len(spacy_tagged)
# Out:
# 262

# %% [markdown]
# Здесь токенизатор также разделил "клауд-грустно", а ещё "очень-очень" и "кто-то". Избавляюсь от "клауд", "очень" и "то" (в последнем случае это не повлияет на результат, так как местоимения и так не входят в оценку)

# %%
spacy_tagged.pop(221)
spacy_tagged.pop(235)
spacy_tagged.pop(238)
# Out:
# {'tag': '-', 'word': 'то'}

# %% [markdown]
# Перераспределяю индексы

# %%
for i in range(221,234):
    spacy_tagged[i] = spacy_tagged[i+1]
for i in range(234, 236):
    spacy_tagged[i] = spacy_tagged[i+2]
for i in range(236, 259):
    spacy_tagged[i] = spacy_tagged[i+3]

# %% [markdown]
# Выкидываю продублировавшийся токен

# %%
spacy_tagged.pop(259)
spacy_tagged.pop(260)
spacy_tagged.pop(261)
# Out:
# {'tag': 'S', 'word': 'песни'}

# %%
spacy_tagged
# Out:
# {0: {'tag': 'ADV', 'word': 'Не'},
#  1: {'tag': 'A', 'word': 'прилично'},
#  2: {'tag': 'ADV', 'word': 'ли'},
#  3: {'tag': 'V', 'word': 'будет'},
#  4: {'tag': '-', 'word': 'нам'},
#  5: {'tag': 'S', 'word': 'братия'},
#  6: {'tag': 'V', 'word': 'Начать'},
#  7: {'tag': 'A', 'word': 'древним'},
#  8: {'tag': 'S', 'word': 'складом'},
#  9: {'tag': 'A', 'word': 'Печальную'},
#  10: {'tag': 'S', 'word': 'повесть'},
#  11: {'tag': 'PR', 'word': 'о'},
#  12: {'tag': 'S', 'word': 'битвах'},
#  13: {'tag': 'S', 'word': 'Игоря'},
#  14: {'tag': 'S', 'word': 'Игоря'},
#  15: {'tag': 'S', 'word': 'Святославича'},
#  16: {'tag': 'V', 'word': 'Начаться'},
#  17: {'tag': 'ADV', 'word': 'же'},
#  18: {'tag': '-', 'word': 'сей'},
#  19: {'tag': 'S', 'word': 'песни'},
#  20: {'tag': 'PR', 'word': 'По'},
#  21: {'tag': 'S', 'word': 'былинам'},
#  22: {'tag': '-', 'word': 'сего'},
#  23: {'tag': 'S', 'word': 'времени'},
#  24: {'tag': 'CONJ', 'word': 'А'},
#  25: {'tag': 'ADV', 'word': 'не'},
#  26: {'tag': 'PR', 'word': 'по'},
#  27: {'tag': 'S', 'word': 'вымыслам'},
#  28: {'tag': 'S', 'word': 'Бояновым'},
#  29: {'tag': 'V', 'word': 'Вещий'},
#  30: {'tag': 'S', 'word': 'Боян'},
#  31: {'tag': 'CONJ', 'word': 'Если'},
#  32: {'tag': 'S', 'word': 'песнь'},
#  33: {'tag': '-', 'word': 'кому'},
#  34: {'tag': 'V', 'word': 'сотворить'},
#  35: {'tag': 'V', 'word': 'хотел'},
#  36: {'tag': 'V', 'word': 'Растекался'},
#  37: {'tag': 'S', 'word': 'мыслию'},
#  38: {'tag': 'PR', 'word': 'по'},
#  39: {'tag': 'S', 'word': 'древу'},
#  40: {'tag': 'A', 'word': 'Серым'},
#  41: {'tag': 'S', 'word': 'волком'},
#  42: {'tag': 'PR', 'word': 'по'},
#  43: {'tag': 'S', 'word': 'земли'},
#  44: {'tag': 'A', 'word': 'Сизым'},
#  45: {'tag': 'S', 'word': 'орлом'},
#  46: {'tag': 'PR', 'word': 'под'},
#  47: {'tag': 'S', 'word': 'облаками'},
#  48: {'tag': '-', 'word': 'Вашу'},
#  49: {'tag': 'S', 'word': 'мысль'},
#  50: {'tag': 'V', 'word': 'мечтающую'},
#  51: {'tag': 'PR', 'word': 'на'},
#  52: {'tag': 'V', 'word': 'размягченном'},
#  53: {'tag': 'S', 'word': 'мозгу'},
#  54: {'tag': 'CONJ', 'word': 'как'},
#  55: {'tag': 'V', 'word': 'выжиревший'},
#  56: {'tag': 'S', 'word': 'лакей'},
#  57: {'tag': 'PR', 'word': 'на'},
#  58: {'tag': 'A', 'word': 'засаленной'},
#  59: {'tag': 'S', 'word': 'кушетке'},
#  60: {'tag': 'V', 'word': 'буду'},
#  61: {'tag': 'V', 'word': 'дразнить'},
#  62: {'tag': 'PR', 'word': 'об'},
#  63: {'tag': 'V', 'word': 'окровавленный'},
#  64: {'tag': 'S', 'word': 'сердца'},
#  65: {'tag': 'S', 'word': 'лоскут'},
#  66: {'tag': 'ADV', 'word': 'досыта'},
#  67: {'tag': 'V', 'word': 'изъиздеваюсь'},
#  68: {'tag': 'A', 'word': 'нахальный'},
#  69: {'tag': 'CONJ', 'word': 'и'},
#  70: {'tag': 'A', 'word': 'едкий'},
#  71: {'tag': 'PR', 'word': 'У'},
#  72: {'tag': '-', 'word': 'меня'},
#  73: {'tag': 'PR', 'word': 'в'},
#  74: {'tag': 'S', 'word': 'душе'},
#  75: {'tag': 'ADV', 'word': 'ни'},
#  76: {'tag': '-', 'word': 'одного'},
#  77: {'tag': 'A', 'word': 'седого'},
#  78: {'tag': 'S', 'word': 'волоса'},
#  79: {'tag': 'CONJ', 'word': 'и'},
#  80: {'tag': 'A', 'word': 'старческой'},
#  81: {'tag': 'S', 'word': 'нежности'},
#  82: {'tag': 'V', 'word': 'нет'},
#  83: {'tag': 'PR', 'word': 'в'},
#  84: {'tag': '-', 'word': 'ней'},
#  85: {'tag': 'S', 'word': 'Мир'},
#  86: {'tag': 'V', 'word': 'огромив'},
#  87: {'tag': 'S', 'word': 'мощью'},
#  88: {'tag': 'S', 'word': 'голоса'},
#  89: {'tag': 'V', 'word': 'иду'},
#  90: {'tag': 'A', 'word': 'красивый'},
#  91: {'tag': 'A', 'word': 'двадцатидвухлетний'},
#  92: {'tag': 'A', 'word': 'Нежные'},
#  93: {'tag': '-', 'word': 'Вы'},
#  94: {'tag': 'S', 'word': 'любовь'},
#  95: {'tag': 'PR', 'word': 'на'},
#  96: {'tag': 'S', 'word': 'скрипки'},
#  97: {'tag': 'V', 'word': 'ложите'},
#  98: {'tag': 'S', 'word': 'Любовь'},
#  99: {'tag': 'PR', 'word': 'на'},
#  100: {'tag': 'S', 'word': 'литавры'},
#  101: {'tag': 'V', 'word': 'ложит'},
#  102: {'tag': 'A', 'word': 'грубый'},
#  103: {'tag': 'CONJ', 'word': 'А'},
#  104: {'tag': '-', 'word': 'себя'},
#  105: {'tag': 'CONJ', 'word': 'как'},
#  106: {'tag': '-', 'word': 'я'},
#  107: {'tag': 'V', 'word': 'вывернуть'},
#  108: {'tag': 'ADV', 'word': 'не'},
#  109: {'tag': 'V', 'word': 'можете'},
#  110: {'tag': 'CONJ', 'word': 'чтобы'},
#  111: {'tag': 'V', 'word': 'были'},
#  112: {'tag': '-', 'word': 'одни'},
#  113: {'tag': 'A', 'word': 'сплошные'},
#  114: {'tag': 'S', 'word': 'губы'},
#  115: {'tag': 'V', 'word': 'Приходите'},
#  116: {'tag': 'V', 'word': 'учиться'},
#  117: {'tag': 'PR', 'word': 'из'},
#  118: {'tag': 'S', 'word': 'гостиной'},
#  119: {'tag': 'A', 'word': 'батистовая'},
#  120: {'tag': 'A', 'word': 'чинная'},
#  121: {'tag': 'S', 'word': 'чиновница'},
#  122: {'tag': 'A', 'word': 'ангельской'},
#  123: {'tag': 'S', 'word': 'лиги'},
#  124: {'tag': 'A', 'word': 'Низкий'},
#  125: {'tag': 'S', 'word': 'дом'},
#  126: {'tag': 'PR', 'word': 'без'},
#  127: {'tag': '-', 'word': 'меня'},
#  128: {'tag': 'V', 'word': 'ссутулится'},
#  129: {'tag': 'A', 'word': 'Старый'},
#  130: {'tag': 'A', 'word': 'пёс'},
#  131: {'tag': '-', 'word': 'мой'},
#  132: {'tag': 'ADV', 'word': 'давно'},
#  133: {'tag': 'V', 'word': 'издох'},
#  134: {'tag': 'PR', 'word': 'На'},
#  135: {'tag': 'A', 'word': 'московских'},
#  136: {'tag': 'V', 'word': 'изогнутых'},
#  137: {'tag': 'S', 'word': 'улицах'},
#  138: {'tag': 'V', 'word': 'Умереть'},
#  139: {'tag': 'V', 'word': 'знать'},
#  140: {'tag': 'V', 'word': 'сулил'},
#  141: {'tag': '-', 'word': 'мне'},
#  142: {'tag': 'S', 'word': 'Бог'},
#  143: {'tag': '-', 'word': 'Я'},
#  144: {'tag': 'V', 'word': 'люблю'},
#  145: {'tag': '-', 'word': 'этот'},
#  146: {'tag': 'S', 'word': 'город'},
#  147: {'tag': 'A', 'word': 'вязевый'},
#  148: {'tag': 'ADV', 'word': 'Пусть'},
#  149: {'tag': 'S', 'word': 'обрюзг'},
#  150: {'tag': '-', 'word': 'он'},
#  151: {'tag': 'CONJ', 'word': 'и'},
#  152: {'tag': 'ADV', 'word': 'пусть'},
#  153: {'tag': 'V', 'word': 'одрях'},
#  154: {'tag': 'A', 'word': 'Золотая'},
#  155: {'tag': 'A', 'word': 'дремотная'},
#  156: {'tag': 'S', 'word': 'Азия'},
#  157: {'tag': 'S', 'word': 'Опочила'},
#  158: {'tag': 'PR', 'word': 'на'},
#  159: {'tag': 'S', 'word': 'куполах'},
#  160: {'tag': 'CONJ', 'word': 'А'},
#  161: {'tag': 'CONJ', 'word': 'когда'},
#  162: {'tag': 'S', 'word': 'ночью'},
#  163: {'tag': 'V', 'word': 'светит'},
#  164: {'tag': 'S', 'word': 'месяц'},
#  165: {'tag': 'CONJ', 'word': 'Когда'},
#  166: {'tag': 'V', 'word': 'светит'},
#  167: {'tag': 'S', 'word': 'чёрт'},
#  168: {'tag': 'V', 'word': 'знает'},
#  169: {'tag': 'CONJ', 'word': 'как'},
#  170: {'tag': '-', 'word': 'Я'},
#  171: {'tag': 'V', 'word': 'иду'},
#  172: {'tag': 'S', 'word': 'головою'},
#  173: {'tag': 'V', 'word': 'свесясь'},
#  174: {'tag': 'A', 'word': 'Переулком'},
#  175: {'tag': 'PR', 'word': 'в'},
#  176: {'tag': 'A', 'word': 'знакомый'},
#  177: {'tag': 'S', 'word': 'кабак'},
#  178: {'tag': 'S', 'word': 'Шум'},
#  179: {'tag': 'CONJ', 'word': 'и'},
#  180: {'tag': 'S', 'word': 'гам'},
#  181: {'tag': 'PR', 'word': 'в'},
#  182: {'tag': '-', 'word': 'этом'},
#  183: {'tag': 'S', 'word': 'логове'},
#  184: {'tag': 'A', 'word': 'жутком'},
#  185: {'tag': 'CONJ', 'word': 'Но'},
#  186: {'tag': '-', 'word': 'всю'},
#  187: {'tag': 'S', 'word': 'ночь'},
#  188: {'tag': 'ADV', 'word': 'напролёт'},
#  189: {'tag': 'PR', 'word': 'до'},
#  190: {'tag': 'S', 'word': 'зари'},
#  191: {'tag': '-', 'word': 'Я'},
#  192: {'tag': 'V', 'word': 'читаю'},
#  193: {'tag': 'S', 'word': 'стихи'},
#  194: {'tag': 'S', 'word': 'проституткам'},
#  195: {'tag': 'CONJ', 'word': 'И'},
#  196: {'tag': 'PR', 'word': 'с'},
#  197: {'tag': 'S', 'word': 'бандитами'},
#  198: {'tag': 'V', 'word': 'жарю'},
#  199: {'tag': 'S', 'word': 'спирт'},
#  200: {'tag': 'S', 'word': 'Седое'},
#  201: {'tag': 'PR', 'word': 'в'},
#  202: {'tag': 'S', 'word': 'джинсах'},
#  203: {'tag': 'PR', 'word': 'от'},
#  204: {'tag': 'S', 'word': 'кутюр'},
#  205: {'tag': 'S', 'word': 'Абсурд'},
#  206: {'tag': 'S', 'word': 'карикатура'},
#  207: {'tag': 'S', 'word': 'Смешно'},
#  208: {'tag': 'PR', 'word': 'в'},
#  209: {'tag': 'S', 'word': 'стране'},
#  210: {'tag': 'S', 'word': 'мультикультур'},
#  211: {'tag': 'V', 'word': 'Закончилась'},
#  212: {'tag': 'S', 'word': 'культура'},
#  213: {'tag': 'CONJ', 'word': 'И'},
#  214: {'tag': 'S', 'word': 'свет'},
#  215: {'tag': 'V', 'word': 'погас'},
#  216: {'tag': 'CONJ', 'word': 'и'},
#  217: {'tag': 'S', 'word': 'гроб'},
#  218: {'tag': 'A', 'word': 'готов'},
#  219: {'tag': 'CONJ', 'word': 'И'},
#  220: {'tag': '-', 'word': 'мне'},
#  222: {'tag': 'PR', 'word': 'В'},
#  223: {'tag': 'S', 'word': 'стране'},
#  224: {'tag': 'A', 'word': 'есенинских'},
#  225: {'tag': 'S', 'word': 'стихов'},
#  226: {'tag': 'V', 'word': 'Закончилось'},
#  227: {'tag': 'S', 'word': 'искусство'},
#  228: {'tag': 'S', 'word': 'Рояльчик'},
#  229: {'tag': 'PR', 'word': 'в'},
#  230: {'tag': 'S', 'word': 'парке'},
#  231: {'tag': 'A', 'word': 'городском'},
#  232: {'tag': 'S', 'word': 'Расстроен'},
#  233: {'tag': 'ADV', 'word': 'очень'},
#  234: {'tag': 'CONJ', 'word': 'И'},
#  236: {'tag': 'A', 'word': 'страшный'},
#  237: {'tag': 'S', 'word': 'жмёт'},
#  239: {'tag': 'S', 'word': 'нём'},
#  240: {'tag': 'S', 'word': 'Бемоль'},
#  241: {'tag': 'A', 'word': 'чернее'},
#  242: {'tag': 'S', 'word': 'ночи'},
#  243: {'tag': 'CONJ', 'word': 'И'},
#  244: {'tag': 'PR', 'word': 'в'},
#  245: {'tag': 'A', 'word': 'чёрном'},
#  246: {'tag': 'S', 'word': 'худи'},
#  247: {'tag': 'V', 'word': 'бродит'},
#  248: {'tag': 'ADV', 'word': 'там'},
#  249: {'tag': 'A', 'word': 'Провинциальный'},
#  250: {'tag': 'S', 'word': 'Бэнкси'},
#  251: {'tag': 'S', 'word': 'Баллоном'},
#  252: {'tag': 'S', 'word': 'строчки'},
#  253: {'tag': 'PR', 'word': 'по'},
#  254: {'tag': 'S', 'word': 'углам'},
#  255: {'tag': 'S', 'word': 'Слова'},
#  256: {'tag': 'PR', 'word': 'из'},
#  257: {'tag': '-', 'word': 'этой'},
#  258: {'tag': 'S', 'word': 'песни'},
#  221: {'tag': 'ADV', 'word': 'грустно'},
#  235: {'tag': '-', 'word': 'кто'},
#  238: {'tag': 'PR', 'word': 'на'}}

# %% [markdown]
# Теперь длина сходится

# %%
len(spacy_tagged)
# Out:
# 259

# %% [markdown]
# # 3. Измерение качества

# %% [markdown]
# ## 3.1. pymorphy

# %%
right = 0
wrong = 0
for num, val in tagged.items():
    if val['tags'][0] != '-': # В оценке не участвуют токены, отмеченные как "-"
        if pymorphy_tagged[num] in val['tags']: 
            # Если тэг автоматической разметки есть среди возможных тэгов, то результат засчитывается как верный, 
            # иначе - неверный
            right += 1
        else:
            wrong += 1

# %%
accuracy = right / (right+wrong)
accuracy
# Out:
# 0.9828326180257511

# %% [markdown]
# ## 3.2. mystem

# %%
right = 0
wrong = 0
for num, val in tagged.items():
    if val['tags'][0] != '-':
        if mystem_tagged[num]['tag'] in val['tags']:
            right += 1
        else:
            wrong += 1

# %%
accuracy = right / (right+wrong)
accuracy
# Out:
# 0.9785407725321889

# %% [markdown]
# ## 3.3. spacy

# %%
right = 0
wrong = 0
for num, val in tagged.items():
    if val['tags'][0] != '-':
        if spacy_tagged[num]['tag'] in val['tags']:
            right += 1
        else:
            wrong += 1

# %%
accuracy = right / (right+wrong)
accuracy
# Out:
# 0.9399141630901288

# %% [markdown]
# Итого, лучше всего справился pymorphy, с ним и будем работать дальше

# %% [markdown]
# # 4. Чанкер

# %% [markdown]
# ## 4.1. Шаблоны

# %% [markdown]
# Шаблон 1: плохо + V, как маркер отрицательного отзыва, потому что "плохо работает", "плохо справился [с задачей]" итд.<br>
# Шаблон 2: осторожно + S, как маркер отрицательного отзыва, так как обычно "осторожно мошенники".<br>
# Шаблон 3: достаточно + A, как маркер положительного отзыва, потому что "достаточно хороший", "достаточно быстрый" (причём именно в положительном ключе) итд.

# %% [markdown]
# ## 4.2. Создание чанкера

# %%
def chunker(text):
    positive = 0
    negative = 0
    tokens = tokenizer.tokenize(text.lower()) # токенизирую
    for i in range(len(tokens)):
        word = tokens[i].strip('.,!?:…—') # чищу токены
        # 1. ищу первый шаблоон, за каждый найденный шаблон, добавляю балл к негативной оценке
        if word == 'плохо' and i < len(tokens) - 1:
            next_word = tokens[i+1].strip('.,!?:…—')
            if m.parse(next_word)[0].tag.POS != None: 
                # проверяю, не является ли токен, идущий сразу за первым пунктуацией или другим мусором,
                # если нет, то рассматриваю его, если является, то смотрю на следующий токен
                if pymorphy_conv[m.parse(next_word)[0].tag.POS] == 'V':
                    negative += 1
            elif i < len(tokens) - 2:
                second_next = tokens[i+2].strip('.,!?:…—')
                if m.parse(second_next)[0].tag.POS != None and \
                                                        pymorphy_conv[m.parse(second_next)[0].tag.POS] == 'V':
                    negative += 1
        # 2. ищу второй шаблоон, за каждый найденный шаблон, добавляю балл к негативной оценке (аналогично)
        if word == 'осторожно' and i < len(tokens) - 1:
            next_word = tokens[i+1].strip('.,!?:…—')
            if m.parse(next_word)[0].tag.POS != None:
                if pymorphy_conv[m.parse(next_word)[0].tag.POS] == 'S':
                    negative += 1
            elif i < len(tokens) - 2:
                second_next = tokens[i+2].strip('.,!?:…—')
                if m.parse(second_next)[0].tag.POS != None and \
                                                    pymorphy_conv[m.parse(second_next)[0].tag.POS] == 'S':
                    negative += 1
        # 3. ищу третий шаблоон, за каждый найденный шаблон, добавляю балл к положительной оценке (аналогично)
        if word == 'довольно' and i < len(tokens) - 1:
            next_word = tokens[i+1].strip('.,!?:…—')
            if m.parse(next_word)[0].tag.POS != None:
                if pymorphy_conv[m.parse(next_word)[0].tag.POS] == 'A':
                    positive += 1
            elif i < len(tokens) - 2:
                second_next = tokens[i+2].strip('.,!?:…—')
                if m.parse(second_next)[0].tag.POS != None and \
                                                    pymorphy_conv[m.parse(second_next)[0].tag.POS] == 'A':
                    positive += 1
    # возвращаю разницу между позитивной оценкой и негативной
    return positive-negative

# %% [markdown]
# ## 4.3. Встраивание чанкера

# %%
# в функцию из предыдущего домашнего задания добавляю в подсчёте оценки оценку чанкера, если activate_chunker=True
def tone_pred(texts, pos_set, neg_set, activate_chunker=False):
    y_pred = []
    for text in texts:
        val = 0
        for token in casual_tokenize(text, preserve_case=False): #токенизирую отзыв, тональность которого угадывается
            features = m.parse(token)[0] 
            if not(features.tag.POS): #не учитываю пунктуацию и мусор
                continue
            lemma = features.normal_form #лемматиизирую
            if lemma in pos_set: #если слово находится в положительном списке, то к оценке тональности прибавляю 1
                val += 1
            if lemma in neg_set: #если слово находится в отрицательном списке, то от оценки тональности отнимаю 1
                val -= 1
        if activate_chunker:
            val += chunker(text)
        if val > 0: #смотрю на знак оценки тональности и по нему делаю предсказание
            y_pred.append(1)
        if val < 0:
            y_pred.append(-1)
        if val == 0:
            y_pred.append(0)
    return(y_pred)

# %% [markdown]
# ## 4.4. Проверка качества

# %% [markdown]
# Здесь я прогоняю код подготовки словарей и тестовой выборки из предыдущего домашнего задания. Только здесь я увеличил размер тестовой выборки до 40 отзывов

# %%
import numpy as np
import random

with open('reviews.json', 'r', encoding='utf-8') as f:
    reviews = json.load(f)

random.seed(1)
len_neg = np.array([len(i) for i in reviews['negative']])
reviews['negative'] = random.choices(np.array(reviews['negative'])[len_neg > 535], k=100)
test = reviews['negative'][-20:]
reviews['negative'] = reviews['negative'][:-20]
test.extend(reviews['positive'][-20:])
reviews['positive'] = reviews['positive'][:-20]
y = [-1 for i in range(20)]
y.extend([1 for i in range(20)])

from nltk.tokenize import casual_tokenize
neg_prep = []
pos_prep = []
for review in reviews['negative']:
    neg_prep.append(casual_tokenize(review, preserve_case=False))
for review in reviews['positive']:
    pos_prep.append(casual_tokenize(review, preserve_case=False))
    
neg_lemma = []
pos_lemma = []
for review in neg_prep:
    rev_lemma = []
    for word in review:
        features = m.parse(word)[0]
        if not(features.tag.POS): #на этом моменте я избавляюсь от пунктуации и мусора
            continue
        rev_lemma.append(features.normal_form)
    neg_lemma.append(rev_lemma)

for review in pos_prep:
    rev_lemma = []
    for word in review:
        features = m.parse(word)[0]
        if not(features.tag.POS):
            continue
        rev_lemma.append(features.normal_form)
    pos_lemma.append(rev_lemma)
    
from collections import Counter
neg_count = Counter([word for review in neg_lemma for word in review])
pos_count = Counter([word for review in pos_lemma for word in review])
neg_words = np.array([i for i in neg_count.keys()])
neg_vals = np.array([i for i in neg_count.values()])
pos_words = np.array([i for i in pos_count.keys()])
pos_vals = np.array([i for i in pos_count.values()])
neg_set = set(neg_words[neg_vals > 4])
pos_set = set(pos_words[pos_vals > 4])
unique_neg = neg_set.difference(pos_set)
unique_pos = pos_set.difference(neg_set)

# %% [markdown]
# Измеряю качество без чанкера

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y, tone_pred(test, unique_pos, unique_neg))
# Out:
# 0.55

# %% [markdown]
# И с чанкером

# %%
accuracy_score(y, tone_pred(test, unique_pos, unique_neg, activate_chunker=True))
# Out:
# 0.575

# %% [markdown]
# С чанкером получилось немного лучше. Дело в том, что такие шаблоны могут встречаться довольно нечасто, и чтобы увидеть значительное улучшение, нужно либо увеличить их количество, либо увеличить размер тестовой выборки
